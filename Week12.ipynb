# %% [markdown]
# <a href="https://colab.research.google.com/github/faizarindra/PCVK_Genap_2023/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import numpy as np
import PIL
import io
import html
import time
# %matplotlib inline

def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
cascade_rai = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Modul12/haarcascade_frontalface_alt.xml')

jokowi = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/jokowi.jpg',0)
woi_rai = cascade_rai.detectMultiScale(jokowi)
for(x,y,w,h) in woi_rai:cv2.rectangle(jokowi,(x,y),(x+w,y+h),(255,255,255),3)
plt.figure(figsize = (10,10))
plt.imshow(jokowi, cmap='gray')

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
cascade_rai = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Modul12/haarcascade_frontalface_alt.xml')


jokowi = cv2.imread('photo.jpg',0)
woi_rai = cascade_rai.detectMultiScale(jokowi)
for(x,y,w,h) in woi_rai:cv2.rectangle(jokowi,(x,y),(x+w,y+h),(255,255,255),3)
plt.figure(figsize = (8,8))
plt.imshow(jokowi, cmap='gray')

# %%
pais1 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/jokowi.jpg')
pais2 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/jokowi.jpg')

pais3 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/kartini.jpg')
pais4 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/kartini.jpg')

pais5 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mycat.jpg',0)
pais6 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mycat.jpg',0)

pais7 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mask.png',0)
pais8 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mask.png',0)

pais9 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mjordan.jpg',0)
pais10 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mjordan.jpg',0)

pais11 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/solvayconf.jpg')
pais12 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/solvayconf.jpg')

faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

faces_rects = faceCascade.detectMultiScale(pais1, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(pais1, (x, y), (x+w, y+h), (0, 255, 0), 5)

faces_rects = faceCascade.detectMultiScale(pais4, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(pais4, (x, y), (x+w, y+h), (0, 255, 0), 5)

faces_rects = faceCascade.detectMultiScale(pais6, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(pais6, (x, y), (x+w, y+h), (0, 255, 0), 5)

faces_rects = faceCascade.detectMultiScale(pais8, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(pais8, (x, y), (x+w, y+h), (0, 255, 0), 5)

faces_rects = faceCascade.detectMultiScale(pais10, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(pais10, (x, y), (x+w, y+h), (0, 255, 0), 3)

faces_rects = faceCascade.detectMultiScale(pais12, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(pais12, (x, y), (x+w, y+h), (0, 255, 0), 3)


f, axarr = plt. subplots(6,2,figsize=(15,10))
plt.subplot(321),plt.imshow(convertToRGB(pais2))
plt.subplot(322),plt.imshow(convertToRGB(pais1))

plt.subplot(323),plt.imshow(convertToRGB(pais3))
plt.subplot(324),plt.imshow(convertToRGB(pais4))

plt.subplot(325),plt.imshow(convertToRGB(pais5))
plt.subplot(326),plt.imshow(convertToRGB(pais6))

f, axarr = plt. subplots(6,2,figsize=(15,10))
plt.subplot(321),plt.imshow(convertToRGB(pais7))
plt.subplot(322),plt.imshow(convertToRGB(pais8))

plt.subplot(323),plt.imshow(convertToRGB(pais9))
plt.subplot(324),plt.imshow(convertToRGB(pais10))

plt.subplot(325),plt.imshow(convertToRGB(pais11))
plt.subplot(326),plt.imshow(convertToRGB(pais12))
# Out:
# <ipython-input-23-e51bcb1f1b34>:55: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(321),plt.imshow(convertToRGB(pais2))
# <ipython-input-23-e51bcb1f1b34>:56: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(322),plt.imshow(convertToRGB(pais1))
# <ipython-input-23-e51bcb1f1b34>:58: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(323),plt.imshow(convertToRGB(pais3))
# <ipython-input-23-e51bcb1f1b34>:59: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
# ...

# %%
cascade_kocheng = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalcatface.xml")

pus = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mycat.jpg',0)
pus1 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mycat.jpg',0)
woi_kocheng = cascade_kocheng.detectMultiScale(pus1)
for(x,y,w,h) in woi_kocheng:cv2.rectangle(pus1,(x,y),(x+w,y+h),(255,255,255),5)
f, axarr = plt. subplots(1,2,figsize=(10,10))
plt.subplot(121),plt.imshow(convertToRGB(pus))
plt.subplot(122),plt.imshow(convertToRGB(pus1))
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7f372faa4ac0>)

# %%
cascade_owi = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

owi = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/jokowi.jpg',0)
owi1 = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/jokowi.jpg',0)
woi_eye = cascade_owi.detectMultiScale(owi1)
for(x,y,w,h) in woi_eye:cv2.rectangle(owi1,(x,y),(x+w,y+h),(255,255,255),5)
f, axarr = plt. subplots(1,2,figsize=(10,10))
plt.subplot(121),plt.imshow(convertToRGB(owi))
plt.subplot(122),plt.imshow(convertToRGB(owi1))
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7f372fe49ea0>)

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Modul12/haarcascade_frontalface_alt.xml')
img = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/mjordan.jpg')
smile = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/smile.png', cv2.IMREAD_UNCHANGED)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = cascade_wajah.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in faces:
    smile_resized = cv2.resize(smile, (w, h))
    img[y:y+h, x:x+w] = cv2.addWeighted(img[y:y+h, x:x+w], 1, smile_resized[:, :, 0:3], 1, 0)

f, axarr = plt. subplots(figsize=(6,6))
plt.subplot(121), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# <ipython-input-3-09fa6e849932>:13: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(121), plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
input_image = cv2.imread('/content/drive/MyDrive/PCVK/Modul12/people.jpg')
gray_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2GRAY)

face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Modul12/haarcascade_frontalface_alt.xml')
faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5)

for (x, y, w, h) in faces:
    cv2.rectangle(input_image, (x, y), (x+w, y+h), (0, 0, 0), 2)

    roi_gray = gray_image[y:y+h, x:x+w]
    eye_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/PCVK/Modul12/haarcascade_eye.xml')
    eyes = eye_cascade.detectMultiScale(roi_gray, scaleFactor=1.1, minNeighbors=5)

    for (ex, ey, ew, eh) in eyes:
        cv2.rectangle(input_image, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 0, 255), 2)

        if ex + ew/2 > w/2:
            cv2.rectangle(input_image, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (255, 255, 255), 2)

plt.figure(figsize=(20, 20))
plt.subplot(122), plt.imshow(cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB))
plt.title('Result'), plt.xticks([]), plt.yticks([])
plt.show()
