# %% [markdown]
# <a href="https://colab.research.google.com/github/faizarindra/PCVK_Genap_2023/blob/main/Modul5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import glob
from math import log10, sqrt

# %%
# Tugas No 1
pais=cv.imread('/content/drive/MyDrive/PCVK/Modul5/female.tiff')
pais2=cv.cvtColor(pais,cv.COLOR_BGR2RGB)
plt.imshow(pais2)

# %%
print('Gamma Correction pada citra ')
print('----------------------------------')
try:
  gamma = int(input('Masukkan Nilai Gamma: '))
except ValueError:
  print('Error, Not a Number')

pais3=cv.cvtColor(pais2,cv.COLOR_BGR2RGB)


gamma_pais = np.zeros(pais3.shape, pais.dtype)

for a in range(pais3.shape[0]):
  for b in range(pais3.shape[1]):
    for c in range(pais3.shape[2]):
      gamma_pais[a,b,c] = np.clip(255 * pow(pais3[a,b,c] / 255, (1 / gamma)), 0, 255)

final_frame = cv.hconcat((pais3, gamma_pais))
cv2_imshow(final_frame)
# Out:
# Gamma Correction pada citra
# ----------------------------------
# Masukkan Nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FAA14543970>

# %%
# Tugas No 2
pais5= cv.imread('/content/drive/MyDrive/PCVK/Modul5/female.tiff',cv.IMREAD_GRAYSCALE)
original = cv.cvtColor(pais5, cv.COLOR_BGR2RGB)
depth_image = np.zeros(original.shape, original.dtype)

bit_depth=2
level = 255 / (pow(2,bit_depth)-1)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
      depth_image[y,x] = np.clip(round(original[y,x,0] / level) * level, 0, 255);

final_frame = cv.hconcat((original,depth_image))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FAA146285E0>

# %%
import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK/Modul5/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK/Modul5/noises/*.jpg'):
  n = cv.imread(img)
  cv_img.append(n)

dst = cv_img[0]
noise_number = 4 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0 :
    pass
  else:
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
  mse = np.mean((original - compressed) ** 2)
  if(mse == 0):
    return 100
  max_pixel = 255.0
  psnr = 20* log10(max_pixel / sqrt(mse))
  return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah ', psnr, '(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah  27.541634796940354 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FAA14553FA0>

# %%
dst = cv_img[0]
noise_number = 29 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0: pass
  else : 
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah', psnr,'(dB)')
galaxy_frame = cv.hconcat((original,dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.52743535685663 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FAA13B5F100>

# %%
dst = cv_img[0]
noise_number = 59 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0: pass
  else : 
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah', psnr,'(dB)')
galaxy_frame = cv.hconcat((original,dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.486137698985672 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FAA13CBC5E0>

# %%
dst = cv_img[0]
noise_number = 79 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0: pass
  else : 
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah', psnr,'(dB)')
galaxy_frame = cv.hconcat((original,dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.50277939018023 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FAA13E53370>

# %%
dst = cv_img[0]
noise_number = 99 # jumlah citra array yang di average
for i in range(noise_number):
  if i == 0: pass
  else : 
    alpha = 1.0 / (i + 1)
    beta = 1.0 - alpha
    dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah', psnr,'(dB)')
galaxy_frame = cv.hconcat((original,dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.51300148703066 (dB)
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FAA13D07730>

# %%
#Tugas No 4
pais6 = cv.imread('/content/drive/MyDrive/PCVK/Modul5/couple.tiff')
pais7 = cv.cvtColor(pais6,cv.COLOR_BGR2RGB)
t=pais7.shape[0]
l=pais7.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(pais7.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 30, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 30, (255,255,255), -1)

result = pais7 & mask & mask1 





circle_frame = cv.hconcat((pais7, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256

# %%
# Tugas No 5
t=pais7.shape[0]
l=pais7.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(pais7.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = pais7 | mask & mask1 

circle_frame = cv.hconcat((pais7, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256

# %%
# Tugas No 5
t=pais7.shape[0]
l=pais7.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(pais7.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = ~pais7 & ~mask

circle_frame = cv.hconcat((pais7, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256

# %%
# Tugas No 5
t=pais7.shape[0]
l=pais7.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(pais7.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = ~pais7 & mask

circle_frame = cv.hconcat((pais7, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256

# %%
# Tugas No 5
t=pais7.shape[0]
l=pais7.shape[1]
print("t = ",t,"l = ",l)

mask = np.zeros(pais7.shape,dtype=np.uint8)
mask = cv.circle(mask,(200, 40), 35, (255,255,255), -1)
mask1 = cv.circle(mask,(75,25), 35, (255,255,255), -1)

result = pais7 ^ mask

circle_frame = cv.hconcat((pais7, result))
plt.imshow(circle_frame)
# Out:
# t =  256 l =  256
